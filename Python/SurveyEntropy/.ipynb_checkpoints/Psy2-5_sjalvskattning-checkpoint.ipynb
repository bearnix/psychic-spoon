# %%
import pandas as pd
import numpy as np
import seaborn as sea

# %%
df = pd.read_csv('../../../../Downloads/2-5/Grupparbete/Personlighetsformular.csv')

# %%
#Column name parsing
new_names = {}
old_name_list = df.columns
old_name_list.to_list()
print(old_name_list)
new_names[ old_name_list[0] ] = "time"
new_names[ old_name_list[-3]] = "ControlItem"
new_names[ old_name_list[-2]] = "Sex"
new_names[ old_name_list[-1]] = "Age"

#old_name_list.pop(-1)
#old_name_list.pop(0)
j=1
for i in range(1, len(old_name_list)-3):
    new_names[old_name_list[i]] = "Item"+str(j)
    j=j+1
#print(new_names)

df = df.rename(columns = new_names)
print(df.columns)
# Out:
# Index(['Timestamp',
#        'Om jag kommer fram till min destination och det öppnar om en kvart har jag inga problem att stanna kvar och vänta tills det öppnar.',
#        'Jag upplever ofta att maten dröjer för länge när jag är ute på restaurang.',
#        'Jag blir irriterad när någon pratar långsamt.',
#        'När jag åker buss tycker jag om att titta ut genom fönstret utan musik eller annan underhållning. ',
#        'Jag kan se en hel film utan att ta upp telefonen eller pausa filmen för att göra något annat.',
#        'Jag är mindre tålmodig än de i min omgivning.',
#        'Köer är det värsta jag vet.',
#        'Om någon går långsamt måste jag gå om dem. ',
#        'Jag kan stå stilla hela vägen upp för rulltrappan. ',
#        'Jag ställer mig upp innan dörrarna öppnat på flygplanet. ',
#        'Jag ställer mig upp innan bussen är framme på min hållplats.',
#        'Jag blir arg när jag hamnar bakom en EPA-traktor (som förare eller passagerare). ',
#        'Jag har svårt att läsa ut böcker.',
#        'Jag kör alltid om bilen framför mig, om jag kan. ',
#        'Om en serie är tråkig slutar jag titta innan första avsnittet är slut.',
#        'Jag tycker att det är fruktansvärt att vänta på information från andra (till exempel emails, tentaresultat, dokument).',
#        'Jag provsmakar alltid det jag köpt innan jag kommer hem.',
#        'Jag har inga problem med att ta långa promenader utan att ta upp telefonen eller lyssna på musik.',
#        'Jag går snabbare än andra människor i min omgivning. ',
#        'Jag cyklar/ tar bilen istället för att gå, även om det inte är långt.',
#        'Jag tycker att det är jobbigt att inte kolla på notiser direkt när jag får dem.',
#        'Om någon tar lång tid på sig att berätta något blir jag otålig. ',
#        'Jag gör hellre saker snabbt och lite slarvigt än långsamt och mer genomtänkt. ',
#        'Jag tycker bättre om att starta upp saker än att avsluta dem. ',
#        'Jag gillar inte att strosa i butiker.',
#        'Jag gillar inte att vänta på andra.',
#        'Jag upplever ofta att andra är för långsamma. ',
#        'Jag gillar att ta min tid. ',
#        'Jag tycker att det är jobbigt om någon tar lång tid på sig i kassan framför mig.',
#        'Jag väljer alltid självutcheckning om jag kan, för att slippa kön. ',
#        'Jag kan bli vansinnig när de framför mig i kassan strular med kortet.',
#        'Andra människor brukar säga till mig att jag har dåligt tålamod. ',
#        'Jag behöver inte vara bra på allt jag gör med en gång.',
#        'Jag tycker om att lära mig nya saker. ',
#        'Jag följer ofta mina paketleveranser noga.',
#        'Jag byter matställe om jag kommer dit och inser att det finns en kö, även om jag ville äta där jag först planerat. ',
#        'Jag hatar att vänta på att bakverk ska bli klara när jag bakar. ',
#        'Jag ogillar uttrycket “den som väntar på något gott väntar aldrig för länge”. ',
#        'Jag tycker att det här formuläret var för långt.',
#        'Jag använder följande sociala medier varje dag: (klicka i de du använder dagligen)',
#        'Jag använder sociala medier mer än personer i min omgivning.',
#        'Hur tålmodig skulle du skatta dig själv från 1-10?', 'Kön', 'Ålder'],
#       dtype='object')
# Index(['time', 'Item1', 'Item2', 'Item3', 'Item4', 'Item5', 'Item6', 'Item7',
#        'Item8', 'Item9', 'Item10', 'Item11', 'Item12', 'Item13', 'Item14',
#        'Item15', 'Item16', 'Item17', 'Item18', 'Item19', 'Item20', 'Item21',
#        'Item22', 'Item23', 'Item24', 'Item25', 'Item26', 'Item27', 'Item28',
#        'Item29', 'Item30', 'Item31', 'Item32', 'Item33', 'Item34', 'Item35',
#        'Item36', 'Item37', 'Item38', 'Item39', 'Item40', 'Item41',
#        'ControlItem', 'Sex', 'Age'],
#       dtype='object')

# %%
remapper = {'Stämmer dåligt': 1, 'Stämmer ganska dåligt': 2, 'Stämmer varken bra eller dåligt': 3, 'Stämmer ganska bra': 4, 'Stämmer bra': 5}
df = df.replace(remapper)
#print(df['Item5'])
# Out:
# /tmp/ipykernel_22177/2280867520.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(remapper)

# %%
sea.histplot(data=df, x='Age', hue='Sex')
#ax.tick_params(axis='x', rotation=90)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
g = sea.histplot(data=df, x='Item40', hue='Age')
g.tick_params(axis='x', rotation=90)

# %%
#for col in ["Comp 7", "Comp 10", "Comp 14", "Comp 21", "Comp 22", "Comp 28", "Comp 29"]:
#    df[col]=6-df[col]
neg_X_mask = df.columns.str.contains('Item40|Age|Sex|ControlItem|time')
X = df.loc[:,~neg_X_mask]
y_mask = df.columns.str.contains("Control*")
y = df.loc[:, y_mask]
print(X)
# Out:
#     Item1  Item2  Item3  Item4  Item5  Item6  Item7  Item8  Item9  Item10  \
# 0       4      2      3      4      3      2      2      2      5       3
# 1       4      2      5      2      3      3      2      5      5       4
# 2       5      4      4      4      5      3      2      5      4       5
# 3       4      4      5      1      2      4      4      5      1       3
# 4       5      4      5      5      1      5      5      5      2       1
# 5       5      4      2      5      1      4      3      4      5       3
# 6       5      5      5      3      2      5      4      5      3       2
# 7       2      3      4      2      2      2      4      4      5       3
# 8       2      3      4      2      4      2      2      4      5       1
# 9       5      2      5      5      3      2      4      4      5       1
# 10      4      4      3      2      2      3      2      4      4       2
# 11      4      2      2      4      2      2      2      4      5       2
# 12      4      2      3      3      4      3      4      2      5       1
# 13      5      1      2      2      3      2      2      4      2       1
# 14      5      3      1      5      5      1      1      1      5       1
# 15      5      4      4      4      5      3      4      2      5       2
# 16      5      1      1      4      4      1      2      2      5       5
# 17      5      1      4      5      2      2      4      5      4       2
# 18      4      3      3      4      4      4      3      3      4       2
# 19      3      1      4      1      3      3      4      5      1       1
# 20      5      2      2      5      3      2      2      5      5       1
# 21      5      3      4      2      4      2      1      1      5       2
# 22      4      1      3      5      5      1      2      3      5       1
# 23      4      3      1      3      5      2      3      3      5       2
# 24      5      1      2      2      2      3      2      4      4       2
# 25      5      3      3      4      2      3      2      2      4       1
# 26      5      3      4      1      1      3      2      5      5       1
# 27      5      1      4      5      5      2      1      4      5       1
# 28      5      3      4      1      4      3      2      5      5       1
# 29      5      3      4      1      2      4      4      4      5       1
# 30      5      4      4      3      1      3      4      5      5       3
# 31      4      2      2      2      3      4      4      4      5       2
# 32      5      3      5      1      1      5      5      5      1       5
# 33      5      3      4      4      2      4      4      5      3       1
# 34      5      4      3      4      1      2      3      5      4       1
# 35      5      1      1      2      4      1      2      2      5       1
# 36      4      4      3      4      2      4      4      3      2       3
#
#     ...  Item31  Item32  Item33  Item34  Item35  Item36  Item37  Item38  \
# 0   ...       3       2       4       4       4       3       2       2
# 1   ...       4       1       2       4       5       1       1       2
# 2   ...       5       4       3       5       5       2       4       1
# 3   ...       2       4       5       5       4       4       4       3
# 4   ...       1       5       5       5       5       3       5       5
# 5   ...       2       3       2       3       4       2       2       2
# 6   ...       1       2       1       5       5       3       4       5
# 7   ...       2       4       1       1       5       4       1       5
# 8   ...       2       1       2       4       2       1       1       1
# 9   ...       2       1       1       5       2       1       2       2
# 10  ...       2       1       2       4       3       2       3       3
# 11  ...       4       1       4       5       1       1       1       2
# 12  ...       4       2       4       4       3       1       2       2
# 13  ...       1       1       5       5       3       1       1       1
# 14  ...       1       1       3       4       1       1       1       3
# 15  ...       1       3       4       5       3       1       1       2
# 16  ...       1       4       5       4       1       1       1       1
# 17  ...       4       2       1       5       5       2       2       2
# 18  ...       2       1       5       5       5       4       4       4
# 19  ...       2       3       1       5       3       4       5       4
# 20  ...       1       2       4       4       3       2       3       2
# 21  ...       2       3       4       4       3       2       1       2
# 22  ...       2       1       4       4       2       3       2       3
# 23  ...       2       1       4       5       1       3       3       4
# 24  ...       2       1       3       5       2       2       2       2
# 25  ...       1       1       2       3       5       2       3       3
# 26  ...       2       1       1       4       5       1       4       3
# 27  ...       1       1       3       5       1       1       1       1
# 28  ...       3       1       5       4       4       3       1       1
# 29  ...       4       3       4       4       4       4       2       3
# 30  ...       3       3       1       5       4       2       1       5
# 31  ...       1       4       2       2       1       2       2       1
# 32  ...       5       1       2       5       1       3       5       5
# 33  ...       3       2       4       4       4       3       2       4
# 34  ...       1       1       2       4       5       1       3       1
# 35  ...       2       1       1       5       3       1       1       3
# 36  ...       4       4       3       4       2       3       2       3
#
#     Item39  Item41
# 0        2       4
# 1        3       4
# 2        2       2
# 3        5       3
# 4        5       2
# 5        5       5
# 6        3       2
# 7        3       2
# 8        4       2
# 9        1       3
# 10       4       3
# 11       1       2
# 12       2       2
# 13       5       1
# 14       3       1
# 15       4       1
# 16       1       2
# 17       4       4
# 18       5       1
# 19       5       4
# 20       3       3
# 21       1       3
# 22       4       1
# 23       3       1
# 24       4       3
# 25       4       4
# 26       3       5
# 27       3       1
# 28       2       3
# 29       4       3
# 30       3       2
# 31       4       5
# 32       3       2
# 33       4       3
# 34       2       2
# 35       3       1
# 36       4       3
#
# [37 rows x 40 columns]

# %%
import matplotlib

from sklearn.inspection import permutation_importance
from sklearn.utils.fixes import parse_version


def plot_permutation_importance(clf, X, y, ax):
    result = permutation_importance(clf, X, y, n_repeats=10, random_state=42, n_jobs=2)
    perm_sorted_idx = result.importances_mean.argsort()

    # `labels` argument in boxplot is deprecated in matplotlib 3.9 and has been
    # renamed to `tick_labels`. The following code handles this, but as a
    # scikit-learn user you probably can write simpler code by using `labels=...`
    # (matplotlib < 3.9) or `tick_labels=...` (matplotlib >= 3.9).
    tick_labels_parameter_name = (
        "tick_labels"
        if parse_version(matplotlib.__version__) >= parse_version("3.9")
        else "labels"
    )
    tick_labels_dict = {tick_labels_parameter_name: X.columns[perm_sorted_idx]}
    ax.boxplot(result.importances[perm_sorted_idx].T, vert=False, **tick_labels_dict)
    ax.axvline(x=0, color="k", linestyle="--")
    return ax

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

#X, y = load_breast_cancer(return_X_y=True, as_frame=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
print(f"Baseline accuracy on test data: {clf.score(X_test, y_test):.2}")
# Out:
# /home/bearnix/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Baseline accuracy on test data: 0.29

# %%
print(X)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

mdi_importances = pd.Series(clf.feature_importances_, index=X_train.columns)
tree_importance_sorted_idx = np.argsort(clf.feature_importances_)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
mdi_importances.sort_values().plot.barh(ax=ax1)
ax1.set_xlabel("Gini importance")
plot_permutation_importance(clf, X_train, y_train, ax2)
ax2.set_xlabel("Decrease in accuracy score")
fig.suptitle(
    "Impurity-based vs. permutation importances on multicollinear features (train set)"
)
_ = fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(7, 6))
plot_permutation_importance(clf, X_test, y_test, ax)
ax.set_title("Permutation Importances on multicollinear features\n(test set)")
ax.set_xlabel("Decrease in accuracy score")
_ = ax.figure.tight_layout()

# %%
import matplotlib.pyplot as plt


from scipy.cluster import hierarchy
from scipy.spatial.distance import squareform
from scipy.stats import spearmanr
from scipy.stats import pearsonr


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
corr = spearmanr(X).correlation
corr2 = np.asarray(X.corr())
corr2 = (corr2 + corr2.T) / 2
# Ensure the correlation matrix is symmetric
corr = (corr + corr.T) / 2
np.fill_diagonal(corr, 1)
np.fill_diagonal(corr2, 1)

# We convert the correlation matrix to a distance matrix before performing
# hierarchical clustering using Ward's linkage.
distance_matrix = 1 - np.abs(corr)
dist_linkage = hierarchy.ward(squareform(distance_matrix))
dendro = hierarchy.dendrogram(
    dist_linkage, labels=X.columns.to_list(), ax=ax1, leaf_rotation=90
)
dendro_idx = np.arange(0, len(dendro["ivl"]))

ax2.imshow(corr[dendro["leaves"], :][:, dendro["leaves"]])
ax2.set_xticks(dendro_idx)
ax2.set_yticks(dendro_idx)
ax2.set_xticklabels(dendro["ivl"], rotation="vertical")
ax2.set_yticklabels(dendro["ivl"])
_ = fig.tight_layout()

# %%
#print(1-abs(corr))
hierarchy.fcluster(dist_linkage, t=0.5, criterion='distance')
# Out:
# array([ 5,  3, 14,  5,  8,  3,  4, 10,  9,  4,  4,  4, 10, 15,  1, 10, 11,
#         4,  2, 12,  3,  3, 16,  4, 14, 10,  5,  6,  3, 13,  7],
#       dtype=int32)

# %%
from collections import defaultdict

cluster_ids = hierarchy.fcluster(dist_linkage, 1, criterion="distance")
cluster_id_to_feature_ids = defaultdict(list)
for idx, cluster_id in enumerate(cluster_ids):
    cluster_id_to_feature_ids[cluster_id].append(idx)
selected_features = [v[0] for v in cluster_id_to_feature_ids.values()]
selected_features_names = X.columns[selected_features]
print(selected_features_names)
X_train_sel = X_train[selected_features_names]
X_test_sel = X_test[selected_features_names]

clf_sel = RandomForestClassifier(n_estimators=100, random_state=42)
clf_sel.fit(X_train_sel, y_train)
print(
    "Baseline accuracy on test data with features removed:"
    f" {clf_sel.score(X_test_sel, y_test):.2}"
)
# Out:
# Index(['Comp 1', 'Comp 3', 'Comp 5', 'Comp 15'], dtype='object')
# /home/bearnix/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Baseline accuracy on test data with features removed: 0.18

# %%
fig, ax = plt.subplots(figsize=(7, 6))
plot_permutation_importance(clf_sel, X_test_sel, y_test, ax)
ax.set_title("Permutation Importances on selected subset of features\n(test set)")
ax.set_xlabel("Decrease in accuracy score")
ax.figure.tight_layout()
plt.show()

# %%
from sklearn.feature_selection import RFE
from sklearn.svm import SVR
#X, y = make_friedman1(n_samples=50, n_features=10, random_state=0)
estimator = SVR(kernel="linear")
selector = RFE(estimator, n_features_to_select=15, step=1)
selector = selector.fit(X, np.asarray(y).ravel())
selector.support_
print(X)
# Out:
#      Comp 1  Comp 2  Comp 3  Comp 4  Comp 5  Comp 6  Comp 7  Comp 8  Comp 9  \
# 0         1       1       1       3       2       2       1       1       5
# 1         1       1       1       1       2       1       1       1       1
# 2         1       2       2       1       5       2       2       2       3
# 3         1       2       1       3       1       2       2       1       3
# 4         2       4       1       1       4       2       2       4       4
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 105       2       3       1       2       1       2       2       2       4
# 106       4       5       4       5       4       5       5       4       5
# 107       1       5       1       2       1       2       1       2       1
# 108       3       3       2       3       4       3       3       4       4
# 109       1       2       1       1       1       1       2       1       3
#
#      Comp 10  ...  Comp 22  Comp 23  Comp 24  Comp 25  Comp 26  Comp 27  \
# 0          2  ...        2        4        1        1        1        2
# 1          1  ...        1        4        1        1        1        1
# 2          2  ...        2        3        3        2        3        2
# 3          2  ...        3        5        3        1        3        2
# 4          2  ...        3        3        2        1        1        2
# ..       ...  ...      ...      ...      ...      ...      ...      ...
# 105        2  ...        3        3        2        1        2        2
# 106        5  ...        5        1        4        2        4        5
# 107        5  ...        2        3        3        1        1        1
# 108        3  ...        3        1        3        3        3        4
# 109        2  ...        3        5        2        1        1        1
#
#      Comp 28  Comp 29  Comp 30  Comp 31
# 0          3        3        1        3
# 1          1        1        2        1
# 2          2        3        3        2
# 3          3        3        2        2
# 4          3        3        2        4
# ..       ...      ...      ...      ...
# 105        3        2        4        2
# 106        4        4        2        4
# 107        2        4        2        3
# 108        3        4        2        2
# 109        3        2        1        1
#
# [110 rows x 31 columns]

# %%
from collections import Counter

# %%
class Item:
    def __init__(self, series):
        self.name = series.name
        self.freq = Counter(series)
        self.prob = self.freq
        tot = sum(self.prob.values())
        for key in self.prob.keys():
            self.prob[key] = self.prob[key]/tot
            
    def entropy(self):
        _entropy = 0.0
        for prob in self.prob.values():
            _entropy -= prob*np.log(prob)
        return _entropy

# %%
i = Item(df['Comp 1'])
# Out:
# 110

# %%
i.name
# Out:
# 'Comp 1'

# %%
i.prob
# Out:
# Counter({1: 0.43636363636363634,
#          2: 0.35454545454545455,
#          3: 0.11818181818181818,
#          4: 0.08181818181818182,
#          5: 0.00909090909090909})

# %%
i.entropy()
#list(df)
#spike_cols = [col for col in df.columns if 'Comp ' in col]
#print(spike_cols)
# Out:
# 1.2294265879227715

# %%
class Survey:
    def __init__(self, df):
        self.items = []
        for item in ( col for col in df.columns if 'Comp ' in col) :
            self.items.append(Item(df[item]))

    def entropy(self):
        _entropy = 0.0
        for item in self.items:
            _entropy += item.entropy()
        return _entropy

# %%
survey = Survey(df)

# %%
survey.entropy()
# Out:
# 44.8164534996561

# %%
survey.entropy()/len(survey.items)
# Out:
# 1.4456920483760032

# %%
for item in survey.items:
    print(item.entropy())
# Out:
# 1.2294265879227715
# 1.5772440061259558
# 1.1276494986719499
# 1.4944201288113055
# 1.5453132292020695
# 1.4990542038831243
# 1.459794357172361
# 1.5395080024661405
# 1.5058841325675445
# 1.4850987372183704
# 1.558801263463559
# 1.4935696596881496
# 1.3679170869850268
# 1.4722485094295894
# 1.4305962168819084
# 1.562987937364845
# 1.4437087017365842
# 1.5577499257629137
# 1.281589689507146
# 1.5811728066889925
# 1.3291592687404623
# 1.5146327727777416
# 1.5662131310856213
# 1.4878389688805538
# 0.9499181861818932
# 1.4335511340011513
# 1.46649678048324
# 1.4229319626525547
# 1.4752966628154405
# 1.4804446393594786
# 1.4762353111276636
